# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
pids = [
    1095377,
    1095378,
    1095379,
    1320734,
    1591462,
    1591463,
    171878,
    171879,
    1887562,
    1887563,
    1887564,
    2062063,
    2099597,
    2100101,
    2100102,
    2100103,
    224835,
    224836,
    224837,
    224838,
    225853,
    225854,
    225855,
    225856,
    225857,
    225858,
    2298998,
    2298999,
    2299721,
    2316714,
    2343891,
    2344330,
    2344331,
    2344332,
    2347227,
    3097300,
    3242932,
    3242933,
    3344187,
    3403381,
    3403382,
    3755815,
    3755816,
    3755817,
    3880445,
    3880446,
    3880447,
    3880448,
    3880449,
    4089146,
    4089147,
    4089148,
    4089149,
    4090234,
    4090235,
    4090236,
    526416,
    526417,
    526418,
    526419,
    541481,
    855909,
    893915,
    893916
];

# %%
df = pd.DataFrame();

# %%
for pid in pids:
    cur = pd.read_csv(f'/data/apc/code_2/{pid}.log',header=None);
    cur[65] = cur[range(6,60)].sum(axis=1);
    df = pd.concat([df, cur], ignore_index=True);

# %%
k=100;
idx = np.argpartition(1.0/(1.0/df[60]+1.0/df[62]+1.0/df[65]),k)[:k];

# %%
opt = df.iloc[idx]

# %%
opt
# Out:
#              0         1         2         3         4         5   6   7   8   \
# 22734  0.762748  0.425900  0.733920  0.743867  0.129672  0.707255   1   1   1
# 12359  0.506588  0.923055  0.355681  0.522889  0.174035  0.191577   1   1   1
# 12362  0.506588  0.923055  0.355681  0.522889  0.174035  0.191577   1   1   1
# 12363  0.506588  0.923055  0.355681  0.522889  0.174035  0.191577   1   1   1
# 12364  0.506588  0.923055  0.355681  0.522889  0.174035  0.191577   1   1   1
# ...         ...       ...       ...       ...       ...       ...  ..  ..  ..
# 22700  0.762748  0.425900  0.733920  0.743867  0.129672  0.707255   1   1   1
# 7938   0.755136  0.070898  0.029051  0.716911  0.206341  0.586683   1   1   1
# 12344  0.506588  0.923055  0.355681  0.522889  0.174035  0.191577   1   1   1
# 12383  0.506588  0.923055  0.355681  0.522889  0.174035  0.191577   1   1   1
# 12840  0.506588  0.923055  0.355681  0.522889  0.174035  0.191577   1   1   1
#
# ...

# %%
fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot(111)
ax.plot(list(1.0/(1.0/opt[60]+1.0/opt[62]+1.0/opt[65]))[:40]);

# %%
opt.iloc[25:30]
# Out:
#              0         1         2         3         4         5   6   7   8   \
# 12378  0.506588  0.923055  0.355681  0.522889  0.174035  0.191577   1   1   1
# 12345  0.506588  0.923055  0.355681  0.522889  0.174035  0.191577   1   1   1
# 12391  0.506588  0.923055  0.355681  0.522889  0.174035  0.191577   1   1   1
# 12397  0.506588  0.923055  0.355681  0.522889  0.174035  0.191577   1   1   1
# 12342  0.506588  0.923055  0.355681  0.522889  0.174035  0.191577   1   1   1
#
#        9   ...  56  57  58  59   60   61     62    63     64  65
# 12378   1  ...   0   0   0   0   72  938  30440  2738  False  21
# 12345   1  ...   0   0   0   0   83  938  26376  2738   True  19
# 12391   1  ...   0   0   0   0   67  938  31331  2738   True  21
# 12397   1  ...   0   0   0   0  126  938  22988  2738   True  19
# 12342   1  ...   0   0   0   0   73  938  31354  2738   True  21
#
# [5 rows x 66 columns]
